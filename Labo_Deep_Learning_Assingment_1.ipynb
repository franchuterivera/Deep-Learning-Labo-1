# %%
import numpy as np
import _pickle as cPickle
import os
import gzip
# %matplotlib inline   
import matplotlib.pyplot as plt

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    return sigmoid(x)*(1-sigmoid(x))

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    return 1-tanh(x)*tanh(x)

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    dx = np.zeros_like(x)
    dx[x > 0] = 1.
    return dx

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1)

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape):
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input):
        return input
    
    def bprop(self, output_grad):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units,
                 init_stddev, dropout=1, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()

        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        num_units_prev = self.input_shape[1]
        hidden_weights_shape = (num_units_prev, num_units)
        self.W = np.random.normal(0,init_stddev,hidden_weights_shape)

        # and this is the bias vector of shape: (num_units)
        hidden_bias_shape = (1, num_units)
        self.b = np.zeros(hidden_bias_shape)

        # create dummy variables for parameter gradients
        # no need to change these here!
        self.dW = None
        self.db = None
        self.dropout = dropout;
        self.do = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units)
    
    def fprop(self, input):
        # TODO ################################################
        # TODO: implement forward propagation
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        #       then this is simply a linear layer
        # TODO ################################################
        # you again want to cache the last_input for the bprop
        # implementation below!
        self.last_input = input
        # NOTE: Use numpy dot product
        # h = t(a), a = W * x + b
        hidden_linear = np.dot(input, self.W) + self.b
        if self.activation_fun == None:
          hidden_act = hidden_linear
        else:
          hidden_act = self.activation_fun.fprop(hidden_linear)
        self.do = np.random.binomial(1, self.dropout, size=hidden_act.shape) / self.dropout
        hidden_act *= self.do
        return hidden_act
        
    def bprop(self, output_grad):
        """ Calculate input gradient (backpropagation). """
        # TODO ################################
        # TODO: implement backward propagation
        # TODO ###############################
        
        # HINT: you may have to divide dW and db by n
        #       to make gradient checking work 
        #       OR you divide the gradient in the output layer by n
        n = output_grad.shape[0]
        # accumulate gradient wrt. the parameters first
        # we will need to store these to later update
        # the network after a few forward backward passes
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        # the gradient wrt. W should be stored as self.dW
        # the gradient wrt. b should be stored as self.db
        # NOTE: self.dW is also a numpy dot product
        output_grad *= self.do
        if self.activation_fun == None:
          hidden_act_grad = output_grad
        else :
          hidden_act_grad = self.activation_fun.bprop(output_grad)
        
        self.dW = np.dot(np.transpose(self.last_input), hidden_act_grad)
        
        self.db = hidden_act_grad.sum(axis=0, keepdims=True)
        
        # the gradient wrt. the input should be calculated here
        grad_input = np.dot(hidden_act_grad, np.transpose(self.W))
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db

# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()

        
    def output_size(self):
        return (1,)
        
    def fprop(self, input):
        return input

    def bprop(self, output_grad):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO ####################################
        # TODO: implement gradient of squared loss
        # TODO ####################################
        ## The error gradient wrt the predicted y value
        ##def squared_error_grad(y_hat, y):
        n_samples = float(Y.shape[0])
        return (Y_pred - Y) / n_samples

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))

class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input):
        return softmax(input)
    
    def bprop(self, output_grad):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # TODO #######################################################
        # TODO: implement gradient of the negative log likelihood loss
        # TODO #######################################################
        # HINT: since this would involve taking the log 
        #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
        #       this gradient computation can be simplified a lot,
        #       you may find a connection to the LinearOutput layer!
        n_samples = float(Y.shape[0])
        return (Y_pred - Y) / n_samples

    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred
        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        eps = 1e-10
        # TODO ####################################
        # calculate negative log likelihood
        # TODO ####################################
        n_samples = float(Y.shape[0])
        loss = np.sum(-np.log(out + eps) * Y, axis=1)
        return np.mean(loss)

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        self.layers = layers
        
    def _loss(self, X, Y):
        Y_pred = self.predict(X)
        
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X):
        """ Calculate an output Y for the given input X. """
        # TODO ##########################################
        # TODO: implement forward pass through all layers
        # TODO ##########################################
        for layer_index in range(len(layers)):
          if layer_index == 0:
            layer_output = layers[layer_index].fprop(X)
          else :
            layer_output = layers[layer_index].fprop(layer_output)
        Y_pred = layer_output
        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        next_grad = self.layers[-1].input_grad(Y, Y_pred)
        # TODO ##########################################
        # TODO: implement backward pass through all layers
        # TODO ##########################################
        for layer_index in reversed(range(upto, len(layers) - 1)):
          next_grad = layers[layer_index].bprop(next_grad)
        return next_grad
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        Y_pred = unhot(self.predict(X))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        for b in range(n_batches):
            # TODO #####################################
            # Implement stochastic gradient descent here
            # TODO #####################################
            # start by extracting a batch from X and Y
            # (you can assume the inputs are already shuffled)

            # TODO: then forward and backward propagation + updates
            # HINT: layer.params() returns parameters *by reference*
            #       so you can easily update in-place
            batch_start = b * batch_size
            batch_end = (b + 1) * batch_size
        
            # Extract the batch from the training set
            X_batch = X[batch_start:batch_end]
            y_batch = Y[batch_start:batch_end]
        
            # Get the gradient via forward and backward pass
            Y_pred = self.predict(X_batch)
            gradients = self.backpropagate(y_batch, Y_pred)
            
            # Update the parameters with the mini-batch gradient
            for layer_index in range(1, len(self.layers)-1):
              #layers[layer_index].W -= learning_rate * layers[layer_index].dW
              #layers[layer_index].b -= learning_rate * layers[layer_index].db
              W,   b = layers[layer_index].params()
              dW, db = layers[layer_index].grad_params()
              W -= learning_rate * dW
              b -= learning_rate * db
    
    def gd_epoch(self, X, Y):
        # TODO ##################################################
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset throught the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        # TODO ##################################################
        # Get the gradient via forward and backward pass
        Y_pred = self.predict(X)
        gradients = self.backpropagate(Y, Y_pred)
            
        # Update the parameters with the mini-batch gradient
        for layer_index in range(1, len(self.layers)-1):
          #layers[layer_index].W -= learning_rate * layers[layer_index].dW
          #layers[layer_index].b -= learning_rate * layers[layer_index].db
          W,   b = layers[layer_index].params()
          dW, db = layers[layer_index].grad_params()
          W -= learning_rate * dW
          b -= learning_rate * db
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):
        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        
        training_loss = np.ones(max_epochs+1) * np.nan
        valid_loss = np.ones(max_epochs+1) * np.nan
        
        if y_one_hot:
            Y_train       = one_hot(Y)
            Y_valid_train = one_hot(Y_valid)
        else:
            Y_train       = Y
            Y_valid_train = Y_valid
        print("... starting training")
        
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            training_loss[e] = self._loss(X, Y_train)
            train_error = self.classification_error(X, Y)
            print('epoch {:.4f}, loss {:.4f}, train error {:.4f}'.format(e, training_loss[e], train_error))
            
            # TODO ##################################################
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            # TODO ##################################################            
         
            # Output error on the training data
            valid_loss[e] = self._loss(X_valid, Y_valid_train)
            valid_error = self.classification_error(X_valid, Y_valid)
            print('epoch {:.4f}, loss {:.4f}, valid error {:.4f}\n'.format(e, valid_loss[e], valid_error))
        # Plot data at the end
        plt.figure(figsize=(12, 8))
        plt.plot(training_loss, label='Training loss')
        plt.plot(valid_loss, label='Validation loss')
        plt.legend(loc='best')
           
    
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l)
                        # return the computed gradient 
                        return np.ravel(self.layers[l].grad_params()[p])

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!
                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params, param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 6
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=15,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(SoftmaxOutput(layers[-1]))
#layers.append(LinearOutput(layers[-1]))

nn = NeuralNetwork(layers)

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1.

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 1.90e-07
# diff scipy 7.00e-08
# checking gradient for layer 2
# diff scipy 1.37e-07
# diff scipy 2.34e-08
# checking gradient for layer 3
# diff scipy 8.09e-08
# diff scipy 1.36e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
X_test, y_test = Dtest
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("\nX_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))

print("\nX_valid shape: {}".format(np.shape(X_valid)))
print("y_valid shape: {}".format(np.shape(y_valid)))

print("\nX_test shape: {}".format(np.shape(X_test)))
print("y_test shape: {}".format(np.shape(y_test)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)
#
# X_valid shape: (10000, 1, 28, 28)
# y_valid shape: (10000,)
#
# X_test shape: (10000, 1, 28, 28)
# y_test shape: (10000,)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
X_test = X_test.reshape((X_test.shape[0], -1))
print("Reshaped X_test size: {}".format(X_test.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)
# Reshaped X_test size: (10000, 784)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=200,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.01,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
#Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.5, 
         max_epochs=30, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
Y_pred = nn.predict(X_test)
error = nn.classification_error(X_test, y_test)
print('\n\n Error in test {:.4f}'.format(error))
# Out:
# ... starting training
# epoch 0.0000, loss 0.1816, train error 0.0562
# epoch 0.0000, loss 0.1773, valid error 0.0542
#
# epoch 1.0000, loss 0.1029, train error 0.0329
# epoch 1.0000, loss 0.1191, valid error 0.0381
#
# epoch 2.0000, loss 0.0885, train error 0.0286
# epoch 2.0000, loss 0.1204, valid error 0.0361
#
# epoch 3.0000, loss 0.0740, train error 0.0246
# epoch 3.0000, loss 0.1128, valid error 0.0327
#
# epoch 4.0000, loss 0.0523, train error 0.0176
# epoch 4.0000, loss 0.1051, valid error 0.0297
#
# epoch 5.0000, loss 0.0442, train error 0.0154
# epoch 5.0000, loss 0.1031, valid error 0.0278
#
# epoch 6.0000, loss 0.0288, train error 0.0095
# epoch 6.0000, loss 0.0931, valid error 0.0249
#
# epoch 7.0000, loss 0.0278, train error 0.0090
# epoch 7.0000, loss 0.0950, valid error 0.0239
#
# epoch 8.0000, loss 0.0217, train error 0.0073
# epoch 8.0000, loss 0.0981, valid error 0.0236
#
# epoch 9.0000, loss 0.0185, train error 0.0064
# epoch 9.0000, loss 0.1020, valid error 0.0237
#
# epoch 10.0000, loss 0.0170, train error 0.0058
# epoch 10.0000, loss 0.1025, valid error 0.0230
#
# epoch 11.0000, loss 0.0098, train error 0.0032
# epoch 11.0000, loss 0.0946, valid error 0.0221
#
# epoch 12.0000, loss 0.0065, train error 0.0023
# epoch 12.0000, loss 0.0901, valid error 0.0199
#
# epoch 13.0000, loss 0.0063, train error 0.0021
# epoch 13.0000, loss 0.0929, valid error 0.0213
#
# epoch 14.0000, loss 0.0024, train error 0.0006
# epoch 14.0000, loss 0.0894, valid error 0.0197
#
# epoch 15.0000, loss 0.0011, train error 0.0002
# epoch 15.0000, loss 0.0872, valid error 0.0185
#
# epoch 16.0000, loss 0.0006, train error 0.0001
# epoch 16.0000, loss 0.0865, valid error 0.0177
#
# epoch 17.0000, loss 0.0005, train error 0.0000
# epoch 17.0000, loss 0.0866, valid error 0.0177
#
# epoch 18.0000, loss 0.0004, train error 0.0000
# epoch 18.0000, loss 0.0873, valid error 0.0175
#
# epoch 19.0000, loss 0.0003, train error 0.0000
# epoch 19.0000, loss 0.0877, valid error 0.0175
#
# epoch 20.0000, loss 0.0003, train error 0.0000
# epoch 20.0000, loss 0.0883, valid error 0.0175
#
# epoch 21.0000, loss 0.0003, train error 0.0000
# epoch 21.0000, loss 0.0888, valid error 0.0175
#
# epoch 22.0000, loss 0.0002, train error 0.0000
# epoch 22.0000, loss 0.0892, valid error 0.0176
#
# epoch 23.0000, loss 0.0002, train error 0.0000
# epoch 23.0000, loss 0.0896, valid error 0.0176
#
# epoch 24.0000, loss 0.0002, train error 0.0000
# epoch 24.0000, loss 0.0900, valid error 0.0175
#
# epoch 25.0000, loss 0.0002, train error 0.0000
# epoch 25.0000, loss 0.0904, valid error 0.0175
#
# epoch 26.0000, loss 0.0002, train error 0.0000
# epoch 26.0000, loss 0.0907, valid error 0.0174
#
# epoch 27.0000, loss 0.0002, train error 0.0000
# epoch 27.0000, loss 0.0910, valid error 0.0175
#
# epoch 28.0000, loss 0.0002, train error 0.0000
# epoch 28.0000, loss 0.0913, valid error 0.0176
#
# epoch 29.0000, loss 0.0001, train error 0.0000
# epoch 29.0000, loss 0.0916, valid error 0.0175
#
# epoch 30.0000, loss 0.0001, train error 0.0000
# epoch 30.0000, loss 0.0919, valid error 0.0175
#
# Duration: 326.7s
#
#
#  Error in test 0.0175

# %% [markdown]
# # Test advanced features

# %%
# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=200,
                init_stddev=0.01,
                dropout = 0.5,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.01,
                dropout = 0.8,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
#Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.5, 
         max_epochs=60, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
Y_pred = nn.predict(X_test)
error = nn.classification_error(X_test, y_test)
print('\n\n Error in test {:.4f}'.format(error))
# Out:
# ... starting training
# epoch 0.0000, loss 0.2942, train error 0.0909
# epoch 0.0000, loss 0.2770, valid error 0.0818
#
# epoch 1.0000, loss 0.2351, train error 0.0718
# epoch 1.0000, loss 0.2257, valid error 0.0672
#
# epoch 2.0000, loss 0.1884, train error 0.0590
# epoch 2.0000, loss 0.1994, valid error 0.0594
#
# epoch 3.0000, loss 0.1672, train error 0.0525
# epoch 3.0000, loss 0.1771, valid error 0.0529
#
# epoch 4.0000, loss 0.1571, train error 0.0488
# epoch 4.0000, loss 0.1732, valid error 0.0522
#
# epoch 5.0000, loss 0.1517, train error 0.0471
# epoch 5.0000, loss 0.1720, valid error 0.0509
#
# epoch 6.0000, loss 0.1361, train error 0.0418
# epoch 6.0000, loss 0.1568, valid error 0.0461
#
# epoch 7.0000, loss 0.1363, train error 0.0419
# epoch 7.0000, loss 0.1581, valid error 0.0463
#
# epoch 8.0000, loss 0.1258, train error 0.0403
# epoch 8.0000, loss 0.1532, valid error 0.0432
#
# epoch 9.0000, loss 0.1199, train error 0.0357
# epoch 9.0000, loss 0.1469, valid error 0.0416
#
# epoch 10.0000, loss 0.1239, train error 0.0368
# epoch 10.0000, loss 0.1580, valid error 0.0431
#
# epoch 11.0000, loss 0.1102, train error 0.0338
# epoch 11.0000, loss 0.1456, valid error 0.0411
#
# epoch 12.0000, loss 0.1012, train error 0.0321
# epoch 12.0000, loss 0.1340, valid error 0.0392
#
# epoch 13.0000, loss 0.0998, train error 0.0326
# epoch 13.0000, loss 0.1451, valid error 0.0410
#
# epoch 14.0000, loss 0.1017, train error 0.0332
# epoch 14.0000, loss 0.1479, valid error 0.0398
#
# epoch 15.0000, loss 0.1026, train error 0.0329
# epoch 15.0000, loss 0.1483, valid error 0.0375
#
# epoch 16.0000, loss 0.0905, train error 0.0286
# epoch 16.0000, loss 0.1330, valid error 0.0371
#
# epoch 17.0000, loss 0.0902, train error 0.0285
# epoch 17.0000, loss 0.1400, valid error 0.0384
#
# epoch 18.0000, loss 0.0878, train error 0.0286
# epoch 18.0000, loss 0.1303, valid error 0.0359
#
# epoch 19.0000, loss 0.0809, train error 0.0267
# epoch 19.0000, loss 0.1352, valid error 0.0362
#
# epoch 20.0000, loss 0.0827, train error 0.0260
# epoch 20.0000, loss 0.1448, valid error 0.0375
#
# epoch 21.0000, loss 0.0922, train error 0.0289
# epoch 21.0000, loss 0.1494, valid error 0.0408
#
# epoch 22.0000, loss 0.0766, train error 0.0246
# epoch 22.0000, loss 0.1400, valid error 0.0354
#
# epoch 23.0000, loss 0.0877, train error 0.0273
# epoch 23.0000, loss 0.1447, valid error 0.0388
#
# epoch 24.0000, loss 0.0835, train error 0.0270
# epoch 24.0000, loss 0.1412, valid error 0.0365
#
# epoch 25.0000, loss 0.0783, train error 0.0236
# epoch 25.0000, loss 0.1387, valid error 0.0328
#
# epoch 26.0000, loss 0.0816, train error 0.0244
# epoch 26.0000, loss 0.1478, valid error 0.0360
#
# epoch 27.0000, loss 0.0748, train error 0.0240
# epoch 27.0000, loss 0.1391, valid error 0.0373
#
# epoch 28.0000, loss 0.0711, train error 0.0234
# epoch 28.0000, loss 0.1321, valid error 0.0379
#
# epoch 29.0000, loss 0.0664, train error 0.0215
# epoch 29.0000, loss 0.1233, valid error 0.0347
#
# epoch 30.0000, loss 0.0758, train error 0.0246
# epoch 30.0000, loss 0.1423, valid error 0.0370
#
# epoch 31.0000, loss 0.0749, train error 0.0240
# epoch 31.0000, loss 0.1454, valid error 0.0407
#
# epoch 32.0000, loss 0.0710, train error 0.0222
# epoch 32.0000, loss 0.1398, valid error 0.0338
#
# epoch 33.0000, loss 0.0680, train error 0.0213
# epoch 33.0000, loss 0.1324, valid error 0.0327
#
# epoch 34.0000, loss 0.0683, train error 0.0214
# epoch 34.0000, loss 0.1260, valid error 0.0350
#
# epoch 35.0000, loss 0.0648, train error 0.0211
# epoch 35.0000, loss 0.1290, valid error 0.0354
#
# epoch 36.0000, loss 0.0668, train error 0.0207
# epoch 36.0000, loss 0.1306, valid error 0.0332
#
# epoch 37.0000, loss 0.0676, train error 0.0221
# epoch 37.0000, loss 0.1392, valid error 0.0339
#
# epoch 38.0000, loss 0.0659, train error 0.0214
# epoch 38.0000, loss 0.1364, valid error 0.0354
#
# epoch 39.0000, loss 0.0699, train error 0.0206
# epoch 39.0000, loss 0.1331, valid error 0.0353
#
# epoch 40.0000, loss 0.0714, train error 0.0226
# epoch 40.0000, loss 0.1371, valid error 0.0374
#
# epoch 41.0000, loss 0.0635, train error 0.0198
# epoch 41.0000, loss 0.1295, valid error 0.0342
#
# epoch 42.0000, loss 0.0624, train error 0.0199
# epoch 42.0000, loss 0.1386, valid error 0.0306
#
# epoch 43.0000, loss 0.0659, train error 0.0208
# epoch 43.0000, loss 0.1379, valid error 0.0341
#
# epoch 44.0000, loss 0.0678, train error 0.0220
# epoch 44.0000, loss 0.1471, valid error 0.0354
#
# epoch 45.0000, loss 0.0581, train error 0.0201
# epoch 45.0000, loss 0.1326, valid error 0.0339
#
# epoch 46.0000, loss 0.0645, train error 0.0195
# epoch 46.0000, loss 0.1421, valid error 0.0334
#
# epoch 47.0000, loss 0.0600, train error 0.0187
# epoch 47.0000, loss 0.1452, valid error 0.0364
#
# epoch 48.0000, loss 0.0610, train error 0.0192
# epoch 48.0000, loss 0.1419, valid error 0.0346
#
# epoch 49.0000, loss 0.0593, train error 0.0189
# epoch 49.0000, loss 0.1364, valid error 0.0333
#
# epoch 50.0000, loss 0.0571, train error 0.0181
# epoch 50.0000, loss 0.1434, valid error 0.0332
#
# epoch 51.0000, loss 0.0625, train error 0.0204
# epoch 51.0000, loss 0.1439, valid error 0.0359
#
# epoch 52.0000, loss 0.0570, train error 0.0188
# epoch 52.0000, loss 0.1416, valid error 0.0342
#
# epoch 53.0000, loss 0.0616, train error 0.0203
# epoch 53.0000, loss 0.1426, valid error 0.0349
#
# epoch 54.0000, loss 0.0564, train error 0.0174
# epoch 54.0000, loss 0.1409, valid error 0.0324
#
# epoch 55.0000, loss 0.0595, train error 0.0183
# epoch 55.0000, loss 0.1441, valid error 0.0349
#
# epoch 56.0000, loss 0.0569, train error 0.0190
# epoch 56.0000, loss 0.1399, valid error 0.0344
#
# epoch 57.0000, loss 0.0520, train error 0.0176
# epoch 57.0000, loss 0.1359, valid error 0.0339
#
# epoch 58.0000, loss 0.0563, train error 0.0184
# epoch 58.0000, loss 0.1391, valid error 0.0318
#
# epoch 59.0000, loss 0.0569, train error 0.0174
# epoch 59.0000, loss 0.1421, valid error 0.0334
#
# epoch 60.0000, loss 0.0544, train error 0.0175
# epoch 60.0000, loss 0.1368, valid error 0.0336
#
# Duration: 654.7s
#
#
#  Error in test 0.0364

# %% [markdown]
# # Massive Train
#
# This group cell is just a test bench to iterate over the data and decide according to a validation, which are the best parameters of the network.
# As the exercise was resolved, it is turned off.

# %%
test_bench = "OFF"
if test_bench == "ON" :
  # Setup a small MLP / Neural Network
  # we can set the first shape to None here to indicate that
  # we will input a variable number inputs to the network
  print("max_epochs,train_loss,train_error,valid_error,activation1,num_units_1,activation2,num_units_2,activation3,learning_rate,max_epochs,duration,error_test")
  for v_learning_rate in [0.1, 0.5, 0.7] :
    for v_activation3 in ['NONE'] :
      for v_activation1 in ['tanh', 'relu', 'sigmoid'] :
        for v_activation2 in ['tanh', 'relu', 'sigmoid'] :
          for v_num_units1 in [100, 200] :
            for v_num_units2 in [50, 100] :
              for v_max_epochs in [30]:
                input_shape = (None, 28*28)
                layers = [InputLayer(input_shape)]
                layers.append(FullyConnectedLayer(
                                layers[-1],
                                num_units=v_num_units1,
                                init_stddev=0.01,
                                activation_fun=Activation(v_activation1)
                ))
                layers.append(FullyConnectedLayer(
                                layers[-1],
                                num_units=v_num_units2,
                                init_stddev=0.01,
                                activation_fun=Activation(v_activation2)
                ))
                if v_activation3 != 'NONE' :
                  layers.append(FullyConnectedLayer(
                                layers[-1],
                                num_units=50,
                                init_stddev=0.01,
                                activation_fun=Activation(v_activation3)
                ))
                layers.append(FullyConnectedLayer(
                                layers[-1],
                                num_units=10,
                                init_stddev=0.01,
                                # last layer has no nonlinearity 
                                # (softmax will be applied in the output layer)
                                activation_fun=None 
                ))
                layers.append(SoftmaxOutput(layers[-1]))

                nn = NeuralNetwork(layers)
                # Train neural network
                t0 = time.time()
                nn.train(X_train, y_train, X_valid, y_valid, learning_rate=v_learning_rate, 
                         max_epochs=v_max_epochs, batch_size=64, y_one_hot=True)
                t1 = time.time()
                Y_pred = nn.predict(X_test)
                error = nn.classification_error(X_test, y_test)
                print('{},{},{},{},{},{},{},{:.1f},{:.4f}'.format(v_activation1,v_num_units1, v_activation2, v_num_units2, v_activation3, v_learning_rate,v_max_epochs, (t1-t0), error))

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=200,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.01,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
#Train neural network
t0 = time.time()
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.5, 
         max_epochs=30, batch_size=64, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
Y_pred = nn.predict(X_test)
error = nn.classification_error(X_test, y_test)
print('\n\n Error in test {:.4f}'.format(error))
# Out:
# ... starting training
# epoch 0.0000, loss 0.1754, train error 0.0554
# epoch 0.0000, loss 0.1775, valid error 0.0566
#
# epoch 1.0000, loss 0.1041, train error 0.0335
# epoch 1.0000, loss 0.1292, valid error 0.0409
#
# epoch 2.0000, loss 0.0804, train error 0.0262
# epoch 2.0000, loss 0.1131, valid error 0.0333
#
# epoch 3.0000, loss 0.0587, train error 0.0193
# epoch 3.0000, loss 0.1032, valid error 0.0318
#
# epoch 4.0000, loss 0.0459, train error 0.0152
# epoch 4.0000, loss 0.0960, valid error 0.0266
#
# epoch 5.0000, loss 0.0373, train error 0.0121
# epoch 5.0000, loss 0.0971, valid error 0.0258
#
# epoch 6.0000, loss 0.0274, train error 0.0097
# epoch 6.0000, loss 0.0908, valid error 0.0231
#
# epoch 7.0000, loss 0.0267, train error 0.0093
# epoch 7.0000, loss 0.1005, valid error 0.0247
#
# epoch 8.0000, loss 0.0174, train error 0.0059
# epoch 8.0000, loss 0.0913, valid error 0.0216
#
# epoch 9.0000, loss 0.0145, train error 0.0047
# epoch 9.0000, loss 0.0996, valid error 0.0229
#
# epoch 10.0000, loss 0.0273, train error 0.0087
# epoch 10.0000, loss 0.1169, valid error 0.0262
#
# epoch 11.0000, loss 0.0121, train error 0.0039
# epoch 11.0000, loss 0.1039, valid error 0.0222
#
# epoch 12.0000, loss 0.0071, train error 0.0022
# epoch 12.0000, loss 0.0963, valid error 0.0214
#
# epoch 13.0000, loss 0.0068, train error 0.0021
# epoch 13.0000, loss 0.1014, valid error 0.0220
#
# epoch 14.0000, loss 0.0027, train error 0.0006
# epoch 14.0000, loss 0.0960, valid error 0.0194
#
# epoch 15.0000, loss 0.0017, train error 0.0003
# epoch 15.0000, loss 0.0958, valid error 0.0193
#
# epoch 16.0000, loss 0.0006, train error 0.0000
# epoch 16.0000, loss 0.0920, valid error 0.0192
#
# epoch 17.0000, loss 0.0005, train error 0.0000
# epoch 17.0000, loss 0.0923, valid error 0.0185
#
# epoch 18.0000, loss 0.0004, train error 0.0000
# epoch 18.0000, loss 0.0925, valid error 0.0183
#
# epoch 19.0000, loss 0.0003, train error 0.0000
# epoch 19.0000, loss 0.0931, valid error 0.0181
#
# epoch 20.0000, loss 0.0003, train error 0.0000
# epoch 20.0000, loss 0.0935, valid error 0.0182
#
# epoch 21.0000, loss 0.0002, train error 0.0000
# epoch 21.0000, loss 0.0939, valid error 0.0182
#
# epoch 22.0000, loss 0.0002, train error 0.0000
# epoch 22.0000, loss 0.0942, valid error 0.0184
#
# epoch 23.0000, loss 0.0002, train error 0.0000
# epoch 23.0000, loss 0.0946, valid error 0.0183
#
# epoch 24.0000, loss 0.0002, train error 0.0000
# epoch 24.0000, loss 0.0949, valid error 0.0183
#
# epoch 25.0000, loss 0.0002, train error 0.0000
# epoch 25.0000, loss 0.0952, valid error 0.0181
#
# epoch 26.0000, loss 0.0002, train error 0.0000
# epoch 26.0000, loss 0.0956, valid error 0.0182
#
# epoch 27.0000, loss 0.0002, train error 0.0000
# epoch 27.0000, loss 0.0958, valid error 0.0180
#
# epoch 28.0000, loss 0.0001, train error 0.0000
# epoch 28.0000, loss 0.0961, valid error 0.0180
#
# epoch 29.0000, loss 0.0001, train error 0.0000
# epoch 29.0000, loss 0.0964, valid error 0.0180
#
# epoch 30.0000, loss 0.0001, train error 0.0000
# epoch 30.0000, loss 0.0967, valid error 0.0180
#
# Duration: 321.5s
#
#
#  Error in test 0.0177
